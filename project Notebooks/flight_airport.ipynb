# %% [markdown]
# So far we've learnt how to scrape the web, and how to make a request for information from an API. Some websites make APIs even easier. Check out [RapidAPI](https://rapidapi.com/) they take care of writing most of the code for you.
#
# We will use the [AeroDataBox API](https://rapidapi.com/aedbx-aedbx/api/aerodatabox/), which can retrieve all sorts of information about flights and airports. We will show you how to retrieve information about the airports, and then it's up to you to apply this, along with what you've already learnt this week, to **produce a function, which retrieves tomorrows flight information for the major airports in the cities you web scraped**.

# %%
import pandas as pd
import requests
from datetime import date

# %% [markdown]
# On the left hand side of the AeroDataBox API page, you'll see a list of options for information that you can retrieve:
# > - Flights API
# - Subsciption / PUSH API
# - Airport API
# - Aircraft API
# - Healthcheck & Status API
#
# 1. We want to select `Airport API`
#
# 2. Then within Airport API we want to select `Search airports by location`
#
# 3. Now in the middle third you'll want to enter the `latitude` and `longitude` of any city to test... we chose Berlin: latitude 52.31 longitude 13.24. Next we changed the `radiusKM` to only 50km. And finally set `withFlightInfoOnly` to true, so it will only return airports which have flight data (scheduled or live) available.
#
# 4. On the right hand third of the screen you should see a block of code that looks pretty unfamiliar. This is because by default the code is probably set to *(Node.js) Axios*. However, we have the power to change this to familiar python. Select the dropdown box at the top of the code and select `python > requests`.
#
# Now you can copy the code to your notebook and it should look a little something like the cell below:

# %%
import requests

url = "https://aerodatabox.p.rapidapi.com/airports/search/location"

querystring = {"lat":"52.31","lon":"13.24","radiusKm":"50","limit":"10","withFlightInfoOnly":"true"}

headers = {
	"X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4", #my api key
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24}, 'count': 1, 'items': [{'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin Brandenburg', 'shortName': 'Brandenburg', 'municipalityName': 'Berlin', 'location': {'lat': 52.35139, 'lon': 13.493889}, 'countryCode': 'DE'}]}

# %% [markdown]
# Let's view the response as `.json()` instead of `.text` so that it's easier to read

# %%
response.json()
# Out:
# {'searchBy': {'lat': 52.31, 'lon': 13.24},
#  'count': 1,
#  'items': [{'icao': 'EDDB',
#    'iata': 'BER',
#    'name': 'Berlin Brandenburg',
#    'shortName': 'Brandenburg',
#    'municipalityName': 'Berlin',
#    'location': {'lat': 52.35139, 'lon': 13.493889},
#    'countryCode': 'DE'}]}

# %% [markdown]
# We can now turn this into a dataframe using `.json_normalize()`

# %%
pd.json_normalize(response.json()['items'])
# Out:
#    icao iata                name    shortName municipalityName countryCode  \
# 0  EDDB  BER  Berlin Brandenburg  Brandenburg           Berlin          DE
#
#    location.lat  location.lon
# 0      52.35139     13.493889

# %% [markdown]
# **airport Dataframe**

# %% [markdown]
# **function**

# %% [markdown]
# Let's now use this for the latitude and longitude of multiple cities

# %%
import pandas as pd
import requests


def get_and_send_airport_data():
    connection_string = connection()
    # coordinates for Berlin, Frankfurt, Cologne, Munich, Hamburg, Hörstel
    latitudes = [52.520008, 50.110924, 50.933594, 48.137154,  53.551086, 51.961563]
    longitudes = [13.404954, 8.682127, 6.961899, 11.576124, 9.993682, 7.628202]
    airport_df = get_airport_data(latitudes, longitudes)
    send_airport_data(airport_df, connection_string)
    return 'airport data sent'

def connection():
  schema = "sql_challenge1"
  host = "127.0.0.1"
  user = "root"
  password = "root1234"
  port = 3306
  connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
  return connection_string


def get_airport_data(latitudes, longitudes):

  list_for_df = []

  for lat,lon in zip(latitudes, longitudes):

    url = f"https://aerodatabox.p.rapidapi.com/airports/search/location/{lat}/{lon}/km/50/10"

    querystring = {"withFlightInfoOnly":"true"}

    headers = {
      "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
      "X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)

    list_for_df.append(pd.json_normalize(response.json()['items']))
    
    airport_data = pd.concat(list_for_df, ignore_index=True)
  airport_df = airport_data.loc[:, ['icao', 'name']]
  return airport_df

def send_airport_data(airport_df, connection_string):
  airport_df.to_sql('airport',
                    if_exists='append',
                    con=connection_string,
                    index=False)
get_and_send_airport_data()
# Out:
# 'airport data sent'

# %% [markdown]
# ###### **Challenge:** Arrivals information
# Using what you have been shown above, plus the skills you've learnt in the last couple of days:
# 1. In `AeroDataBox API` use the `Flight API` > `FIDS/Schedules: Airport departures and arrivals by airport ICAO code` section
# 2. Fill out the parameters in the middle third and then copy the `python: requests` code from the right hand third
# 3. Explore the data you get back. What would be useful in your DataFrame and what can be excluded? Remember Gans wants to know about when people are arriving in the city
# 4. Make a DataFrame from the information you see as important
# 5. Condense everything you did above into a function that can take a list of ICAO codes as an input, and as an output gives you a DataFrame with the information for *tomorrows arrivals*

# %%
import requests
url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EDDB"

querystring = {"offsetMinutes":"-120","durationMinutes":"720","withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response_flight = requests.get(url, headers=headers, params=querystring)

print(response_flight.json())
# Out:
# {'departures': [{'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z', 'local': '2024-03-12 08:40+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:05Z', 'local': '2024-03-12 09:05+01:00'}, 'runwayTime': {'utc': '2024-03-12 08:11Z', 'local': '2024-03-12 09:11+01:00'}, 'terminal': '1', 'checkInDesk': '011-013', 'gate': 'C13', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'}, 'quality': []}, 'number': '6Y 305', 'callSign': 'ART305', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'YR-HLA', 'modeS': '4A2181', 'model': 'Boeing 737-800'}, 'airline': {'name': 'SmartLynx', 'iata': '6Y', 'icao': 'ART'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 07:56Z', 'local': '2024-03-12 08:56+01:00'}, 'revisedTime': {'utc': '2024-03-12 07:56Z', 'local': '2024-03-12 08:56+01:00'}, 'runwayTime': {'utc': '2024-03-12 07:56Z', 'local': '2024-03-12 08:56+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'name': 'Unknown'}, 'quality': []}, 'number': 'ESW 77', 'callSign': 'ESW77', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': '4K-080', 'modeS': '600BCA', 'model': 'Gulfstream Aerospace V'}, 'airline': {'name': 'ESW'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 08:04Z', 'local': '2024-03-12 09:04+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:04Z', 'local': '2024-03-12 09:04+01:00'}, 'runwayTime': {'utc': '2024-03-12 08:06Z', 'local': '2024-03-12 09:06+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'name': 'Unknown'}, 'quality': []}, 'number': 'DFBWG', 'callSign': 'DFBWG', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-FBWG', 'modeS': '3D4E36', 'model': 'Pilatus PC-12'}, 'airline': {'name': 'Unknown/Private owner'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 08:30Z', 'local': '2024-03-12 09:30+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:30Z', 'local': '2024-03-12 09:30+01:00'}, 'runwayTime': {'utc': '2024-03-12 08:40Z', 'local': '2024-03-12 09:40+01:00'}, 'terminal': '1', 'checkInDesk': '514-616', 'gate': 'A36', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'}, 'quality': []}, 'number': 'EC 5051', 'callSign': 'EJU5051', 'status': 'Departed', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'OE-IJW', 'modeS': '44093E', 'model': 'Airbus A320'}, 'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 08:09Z', 'local': '2024-03-12 09:09+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:09Z', 'local': '2024-03-12 09:09+01:00'}, 'runwayTime': {'utc': '2024-03-12 08:09Z', 'local': '2024-03-12 09:09+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'name': 'Unknown'}, 'quality': []}, 'number': 'LXG 74M', 'callSign': 'LXG74M', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-ICBA', 'modeS': '3E1CAA', 'model': 'Cessna 525A'}, 'airline': {'name': 'LXG'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z', 'local': '2024-03-12 09:00+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:00Z', 'local': '2024-03-12 09:00+01:00'}, 'terminal': '1', 'checkInDesk': '323-326', 'gate': 'A03', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'}, 'quality': []}, 'number': 'LH 5386', 'status': 'Departed', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'}, 'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 08:33Z', 'local': '2024-03-12 09:33+01:00'}, 'revisedTime': {'utc': '2024-03-12 08:33Z', 'local': '2024-03-12 09:33+01:00'}, 'runwayTime': {'utc': '2024-03-12 08:36Z', 'local': '2024-03-12 09:36+01:00'}, 'quality': ['Basic',  ...

# %%
response_flight.json()
# Out:
# {'departures': [{'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:11Z',
#      'local': '2024-03-12 09:11+01:00'},
#     'terminal': '1',
#     'checkInDesk': '011-013',
#     'gate': 'C13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#     'quality': []},
#    'number': '6Y 305',
#    'callSign': 'ART305',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YR-HLA', 'modeS': '4A2181', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'SmartLynx', 'iata': '6Y', 'icao': 'ART'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'ESW 77',
#    'callSign': 'ESW77',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4K-080',
#     'modeS': '600BCA',
#     'model': 'Gulfstream Aerospace V'},
#    'airline': {'name': 'ESW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:06Z',
#      'local': '2024-03-12 09:06+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'DFBWG',
#    'callSign': 'DFBWG',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-FBWG', 'modeS': '3D4E36', 'model': 'Pilatus PC-12'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:30Z',
#      'local': '2024-03-12 09:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:30Z',
#      'local': '2024-03-12 09:30+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'quality': []},
#    'number': 'EC 5051',
#    'callSign': 'EJU5051',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJW', 'modeS': '44093E', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'LXG 74M',
#    'callSign': 'LXG74M',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ICBA', 'modeS': '3E1CAA', 'model': 'Cessna 525A'},
#    'airline': {'name': 'LXG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': 'LH 5386',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:33Z',
#      'local': '2024-03-12 09:33+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:33Z',
#      'local': '2024-03-12 09:33+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:36Z',
#      'local': '2024-03-12 09:36+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'QGA 1A',
#    'callSign': 'QGA01A',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-CJJK',
#     'modeS': '3CD8B8',
#     'model': 'Cessna 560 Citation Excel'},
#    'airline': {'name': 'QGA'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:12Z',
#      'local': '2024-03-12 10:12+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A31',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'EC 4076',
#    'callSign': 'EJU14KB',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICP', 'modeS': '440036', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 10:35+01:00'},
#     'terminal': '1',
#     'checkInDesk': '214-216',
#     'gate': 'A32',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LDDU', 'iata': 'DBV', 'name': 'Dubrovnik'},
#     'quality': []},
#    'number': 'MI 8173',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-FHB', 'modeS': '4D21B1', 'model': 'Airbus A320'},
#    'airline': {'name': 'Freebird Airlines Europe'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 11:50Z',
#      'local': '2024-03-12 12:50+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:50Z',
#      'local': '2024-03-12 12:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LCLK', 'iata': 'LCA', 'name': 'Larnarca'},
#     'quality': []},
#    'number': 'EC 5367',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 12:25Z',
#      'local': '2024-03-12 13:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:25Z',
#      'local': '2024-03-12 13:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'quality': []},
#    'number': 'EC 5065',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LKP', 'modeS': '440018', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 13:25Z',
#      'local': '2024-03-12 14:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:25Z',
#      'local': '2024-03-12 14:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'EC 5143',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 13:05Z',
#      'local': '2024-03-12 14:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:05Z',
#      'local': '2024-03-12 14:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': 'LH 5396',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': 'LH 5388',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWF', 'modeS': '3C56E6', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 17:15Z',
#      'local': '2024-03-12 18:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:15Z',
#      'local': '2024-03-12 18:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'number': 'EC 8630',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQW', 'modeS': '440171', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 17:15Z',
#      'local': '2024-03-12 18:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:15Z',
#      'local': '2024-03-12 18:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'number': 'U2 8630',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQW', 'modeS': '440171', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 19:30Z',
#      'local': '2024-03-12 20:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:30Z',
#      'local': '2024-03-12 20:30+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'quality': []},
#    'number': 'EC 4876',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVT', 'modeS': '4400EB', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '621-623',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'BIKF', 'iata': 'KEF', 'name': 'Reykjavik'},
#     'scheduledTime': {'utc': '2024-03-12 15:45Z',
#      'local': '2024-03-12 15:45+00:00'},
#     'revisedTime': {'utc': '2024-03-12 15:45Z',
#      'local': '2024-03-12 15:45+00:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'FI 529',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737 MAX 8 '},
#    'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 11:20Z',
#      'local': '2024-03-12 12:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:20Z',
#      'local': '2024-03-12 12:20+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 12:45Z',
#      'local': '2024-03-12 13:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:45Z',
#      'local': '2024-03-12 13:45+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 162',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QEU', 'modeS': '4D23FD', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B10',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 12:20Z',
#      'local': '2024-03-12 13:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:20Z',
#      'local': '2024-03-12 13:20+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2582',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNJ', 'model': 'Airbus A320-200'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 19:05Z',
#      'local': '2024-03-12 20:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:05Z',
#      'local': '2024-03-12 20:05+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2588',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNM', 'modeS': '44CDCD', 'model': 'Airbus A320'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'DISAG',
#    'callSign': 'DISAG',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ISAG',
#     'modeS': '3E46D6',
#     'model': 'Beechcraft Premier I'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 09:55Z',
#      'local': '2024-03-12 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:55Z',
#      'local': '2024-03-12 10:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 181',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:40Z',
#      'local': '2024-03-12 10:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:40Z',
#      'local': '2024-03-12 10:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 183',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:40Z',
#      'local': '2024-03-12 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:40Z',
#      'local': '2024-03-12 11:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 185',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 11:40Z',
#      'local': '2024-03-12 12:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:40Z',
#      'local': '2024-03-12 12:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 12:55Z',
#      'local': '2024-03-12 13:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:55Z',
#      'local': '2024-03-12 13:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 187',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 12:40Z',
#      'local': '2024-03-12 13:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:40Z',
#      'local': '2024-03-12 13:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 13:55Z',
#      'local': '2024-03-12 14:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:55Z',
#      'local': '2024-03-12 14:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 189',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 13:40Z',
#      'local': '2024-03-12 14:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:40Z',
#      'local': '2024-03-12 14:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 191',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 15:55Z',
#      'local': '2024-03-12 16:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:55Z',
#      'local': '2024-03-12 16:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 193',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 16:40Z',
#      'local': '2024-03-12 17:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:40Z',
#      'local': '2024-03-12 17:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 17:55Z',
#      'local': '2024-03-12 18:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:55Z',
#      'local': '2024-03-12 18:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 197',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 199',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:40Z',
#      'local': '2024-03-12 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:40Z',
#      'local': '2024-03-12 19:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 19:55Z',
#      'local': '2024-03-12 20:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:55Z',
#      'local': '2024-03-12 20:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 201',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-12 15:50Z',
#      'local': '2024-03-12 16:50+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 5',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AGWI', 'modeS': '3C5EE9', 'model': 'Airbus A319'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 16:45Z',
#      'local': '2024-03-12 17:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:45Z',
#      'local': '2024-03-12 17:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-12 17:55Z',
#      'local': '2024-03-12 18:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 51',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWL', 'modeS': '3C56EC', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:20Z',
#      'local': '2024-03-12 19:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:20Z',
#      'local': '2024-03-12 19:20+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-12 19:30Z',
#      'local': '2024-03-12 20:30+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 19',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABNU', 'modeS': '3C49D5', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'B03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-12 09:15Z',
#      'local': '2024-03-12 10:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:01Z',
#      'local': '2024-03-12 10:01+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:58Z',
#      'local': '2024-03-12 09:58+01:00'},
#     'terminal': 'A(1)',
#     'gate': 'B33',
#     'baggageBelt': '04',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9049',
#    'callSign': 'GWI9UW',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDV', 'modeS': '3C6496', 'model': 'Airbus A321'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-12 16:10Z',
#      'local': '2024-03-12 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:10Z',
#      'local': '2024-03-12 17:10+01:00'},
#     'terminal': 'A',
#     'gate': 'A40',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9043',
#    'callSign': 'GWI4SF',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-EWB', 'modeS': '4D2414', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:35Z',
#      'local': '2024-03-12 19:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:35Z',
#      'local': '2024-03-12 19:35+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-12 19:45Z',
#      'local': '2024-03-12 20:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:45Z',
#      'local': '2024-03-12 20:45+01:00'},
#     'terminal': 'A',
#     'gate': 'B91',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9045',
#    'callSign': 'EWG5XH',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:08Z',
#      'local': '2024-03-12 09:08+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B07',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 09:10Z',
#      'local': '2024-03-12 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:50Z',
#      'local': '2024-03-12 09:50+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1929',
#    'callSign': 'DLH3TT',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINW',
#     'modeS': '3C65D7',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:15Z',
#      'local': '2024-03-12 10:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B01',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 10:10Z',
#      'local': '2024-03-12 11:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:10Z',
#      'local': '2024-03-12 11:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1931',
#    'callSign': 'DLH9JK',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B06',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 11:10Z',
#      'local': '2024-03-12 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:10Z',
#      'local': '2024-03-12 12:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1935',
#    'status': 'Boarding',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDJ', 'modeS': '3C648A', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 11:50Z',
#      'local': '2024-03-12 12:50+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:50Z',
#      'local': '2024-03-12 12:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 13:00Z',
#      'local': '2024-03-12 14:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:00Z',
#      'local': '2024-03-12 14:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 2207',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIWD', 'modeS': '3C66E4', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 13:30Z',
#      'local': '2024-03-12 14:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:30Z',
#      'local': '2024-03-12 14:30+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:40Z',
#      'local': '2024-03-12 15:40+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1939',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 14:45Z',
#      'local': '2024-03-12 15:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:45Z',
#      'local': '2024-03-12 15:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 15:55Z',
#      'local': '2024-03-12 16:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:55Z',
#      'local': '2024-03-12 16:55+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1941',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIWG', 'modeS': '3C66E7', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 15:45Z',
#      'local': '2024-03-12 16:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:45Z',
#      'local': '2024-03-12 16:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 16:55Z',
#      'local': '2024-03-12 17:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:55Z',
#      'local': '2024-03-12 17:55+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1943',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUA',
#     'modeS': '3C66A1',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1949',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISP', 'modeS': '3C6670', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 20:05Z',
#      'local': '2024-03-12 21:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 20:05Z',
#      'local': '2024-03-12 21:05+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1951',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZN', 'modeS': '3C674E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:54Z',
#      'local': '2024-03-12 08:54+01:00'},
#     'terminal': '1',
#     'checkInDesk': '521-522',
#     'gate': 'B30',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-12 09:20Z',
#      'local': '2024-03-12 10:20+01:00'},
#     'quality': ['Basic']},
#    'number': 'DX 122',
#    'callSign': 'DTR2HR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'terminal': '1',
#     'checkInDesk': '111-112',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-12 20:30Z',
#      'local': '2024-03-12 21:30+01:00'},
#     'quality': ['Basic']},
#    'number': 'DX 126',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 2003',
#    'callSign': 'GWI2003',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 09:10Z',
#      'local': '2024-03-12 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2003',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 13:05Z',
#      'local': '2024-03-12 14:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 13:05Z',
#      'local': '2024-03-12 14:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 14:15Z',
#      'local': '2024-03-12 15:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:15Z',
#      'local': '2024-03-12 15:15+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8004',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 15:00Z',
#      'local': '2024-03-12 16:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 16:10Z',
#      'local': '2024-03-12 17:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:10Z',
#      'local': '2024-03-12 17:10+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2005',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWF', 'modeS': '3C56E6', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:30Z',
#      'local': '2024-03-12 19:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:30Z',
#      'local': '2024-03-12 19:30+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 19:40Z',
#      'local': '2024-03-12 20:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:40Z',
#      'local': '2024-03-12 20:40+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2021',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWJ', 'modeS': '3C56EA', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'terminal': '1',
#     'checkInDesk': '223-225',
#     'gate': 'A17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 11:35+02:00'},
#     'revisedTime': {'utc': '2024-03-12 09:34Z',
#      'local': '2024-03-12 11:34+02:00'},
#     'terminal': '2',
#     'gate': '20',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1432',
#    'callSign': 'FIN29Y',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKM', 'modeS': '461E1C', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 12:05Z',
#      'local': '2024-03-12 13:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:05Z',
#      'local': '2024-03-12 13:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '211-213',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-12 14:00Z',
#      'local': '2024-03-12 16:00+02:00'},
#     'revisedTime': {'utc': '2024-03-12 14:00Z',
#      'local': '2024-03-12 16:00+02:00'},
#     'terminal': '2',
#     'gate': '25',
#     'baggageBelt': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1434',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-200 (sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 18:10Z',
#      'local': '2024-03-12 19:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:10Z',
#      'local': '2024-03-12 19:10+01:00'},
#     'terminal': '1',
#     'checkInDesk': '211-213',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-12 20:05Z',
#      'local': '2024-03-12 22:05+02:00'},
#     'revisedTime': {'utc': '2024-03-12 20:05Z',
#      'local': '2024-03-12 22:05+02:00'},
#     'terminal': '2',
#     'baggageBelt': '6',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1436',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-200 (sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 16:20Z',
#      'local': '2024-03-12 17:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:20Z',
#      'local': '2024-03-12 17:20+01:00'},
#     'terminal': '2',
#     'checkInDesk': '158-165',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGCC',
#      'iata': 'MAN',
#      'name': 'Manchester'},
#     'scheduledTime': {'utc': '2024-03-12 18:25Z',
#      'local': '2024-03-12 18:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 18:25Z',
#      'local': '2024-03-12 18:25+00:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 1144',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAU', 'modeS': '4D2269', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C06',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'scheduledTime': {'utc': '2024-03-12 12:25Z',
#      'local': '2024-03-12 12:25+00:00'},
#     'quality': ['Basic']},
#    'number': 'U2 2934',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZGJ', 'modeS': '406539', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:30Z',
#      'local': '2024-03-12 10:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 11:25Z',
#      'local': '2024-03-12 11:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 11:20Z',
#      'local': '2024-03-12 11:20+00:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2602',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZDR', 'modeS': '405B6A', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
# ...
#    'number': 'EC 5080',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5144',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-12 16:40Z',
#      'local': '2024-03-12 17:40+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:15Z',
#      'local': '2024-03-12 19:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:15Z',
#      'local': '2024-03-12 19:15+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'DX 125',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'ATR 42-300'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'airport': {'icao': 'LIME', 'iata': 'BGY', 'name': 'Bergamo'},
#     'scheduledTime': {'utc': '2024-03-12 17:00Z',
#      'local': '2024-03-12 18:00+01:00'},
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:40Z',
#      'local': '2024-03-12 19:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:40Z',
#      'local': '2024-03-12 19:40+01:00'},
#     'terminal': '2',
#     'gate': 'Z30',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 3391',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAO', 'modeS': '4D222E', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'J',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'I2 3672',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-OAU',
#     'modeS': '347501',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Iberia Express', 'iata': 'I2', 'icao': 'IBS'}},
#   {'departure': {'airport': {'icao': 'LEMD', 'iata': 'MAD', 'name': 'Madrid'},
#     'scheduledTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 14:55Z',
#      'local': '2024-03-12 15:55+01:00'},
#     'terminal': '4',
#     'checkInDesk': '850-859',
#     'gate': 'J',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'IB 3672',
#    'status': 'Expected',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Iberia', 'iata': 'IB', 'icao': 'IBE'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 17:00Z',
#      'local': '2024-03-12 18:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:00Z',
#      'local': '2024-03-12 18:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:10Z',
#      'local': '2024-03-12 19:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:10Z',
#      'local': '2024-03-12 19:10+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1950',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZN', 'modeS': '3C674E', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 17:45Z',
#      'local': '2024-03-12 18:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:45Z',
#      'local': '2024-03-12 18:45+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'terminal': '1',
#     'gate': 'A10',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 198',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LSZH', 'iata': 'ZRH', 'name': 'Zurich'},
#     'scheduledTime': {'utc': '2024-03-12 17:25Z',
#      'local': '2024-03-12 18:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:25Z',
#      'local': '2024-03-12 18:25+01:00'},
#     'checkInDesk': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'LX 978',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JBE',
#     'modeS': '4B17E2',
#     'model': 'Airbus A220-100'},
#    'airline': {'name': 'SWISS', 'iata': 'LX', 'icao': 'SWR'}},
#   {'departure': {'airport': {'icao': 'LFPO', 'iata': 'ORY', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-12 17:10Z',
#      'local': '2024-03-12 18:10+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:55Z',
#      'local': '2024-03-12 19:55+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 4875',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IVT', 'modeS': '4400EB', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LIRF', 'iata': 'FCO', 'name': 'Rome'},
#     'scheduledTime': {'utc': '2024-03-12 16:40Z',
#      'local': '2024-03-12 17:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:40Z',
#      'local': '2024-03-12 17:40+01:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:50Z',
#      'local': '2024-03-12 19:50+01:00'},
#     'terminal': '1',
#     'gate': 'A34',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5080',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQE', 'modeS': '440732', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'scheduledTime': {'utc': '2024-03-12 16:00Z',
#      'local': '2024-03-12 17:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5144',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 18:25Z',
#      'local': '2024-03-12 19:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:25Z',
#      'local': '2024-03-12 19:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '441-445',
#     'gate': 'A11',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:30Z',
#      'local': '2024-03-12 20:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:30Z',
#      'local': '2024-03-12 20:30+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'A3 4371',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Aegean', 'iata': 'A3', 'icao': 'AEE'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'checkInDesk': '42-50',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:35Z',
#      'local': '2024-03-12 20:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:35Z',
#      'local': '2024-03-12 20:35+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'DS 1187',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JXM', 'modeS': '4B1A26', 'model': 'Airbus A320'},
#    'airline': {'name': 'Easyjet Switzerland', 'iata': 'DS', 'icao': 'EZS'}},
#   {'departure': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 17:55Z',
#      'local': '2024-03-12 17:55+00:00'},
#     'revisedTime': {'utc': '2024-03-12 17:55Z',
#      'local': '2024-03-12 17:55+00:00'},
#     'terminal': '1',
#     'gate': '46',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:40Z',
#      'local': '2024-03-12 20:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:40Z',
#      'local': '2024-03-12 20:40+01:00'},
#     'terminal': '2',
#     'gate': 'Z40',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 147',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QBF', 'modeS': '4D2275', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'LHBP',
#      'iata': 'BUD',
#      'name': 'Budapest'},
#     'scheduledTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'terminal': '2B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 197',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'SP-RNK', 'modeS': '48C1A9', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg'},
#     'scheduledTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 17:40Z',
#      'local': '2024-03-12 18:40+01:00'},
#     'terminal': 'A',
#     'gate': 'B03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'terminal': '1',
#     'gate': 'S01',
#     'baggageBelt': 'B1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LG 9473',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Bombardier Dash 8 Q400 / DHC-8-400'},
#    'airline': {'name': 'Luxair', 'iata': 'LG', 'icao': 'LGL'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:05Z',
#      'local': '2024-03-12 19:05+01:00'},
#     'checkInDesk': '42-50',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:35Z',
#      'local': '2024-03-12 20:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:35Z',
#      'local': '2024-03-12 20:35+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 1187',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'HB-JXM', 'modeS': '4B1A26', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-12 16:45Z',
#      'local': '2024-03-12 17:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 16:45Z',
#      'local': '2024-03-12 17:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'B',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:25Z',
#      'local': '2024-03-12 20:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:25Z',
#      'local': '2024-03-12 20:25+01:00'},
#     'terminal': '2',
#     'gate': 'Z32',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1884',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-NLV', 'modeS': '346690', 'model': 'Airbus A321'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 18:00Z',
#      'local': '2024-03-12 19:00+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 19:10Z',
#      'local': '2024-03-12 20:10+01:00'},
#     'terminal': '1',
#     'gate': 'B20',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1954',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBC', 'modeS': '3C6443', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}}]}

# %%
#first item in departure dictionary
response_flight.json()['departures'][0]
# Out:
# {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#    'local': '2024-03-12 08:40+01:00'},
#   'revisedTime': {'utc': '2024-03-12 08:05Z',
#    'local': '2024-03-12 09:05+01:00'},
#   'runwayTime': {'utc': '2024-03-12 08:11Z',
#    'local': '2024-03-12 09:11+01:00'},
#   'terminal': '1',
#   'checkInDesk': '011-013',
#   'gate': 'C13',
#   'quality': ['Basic', 'Live']},
#  'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#   'quality': []},
#  'number': '6Y 305',
#  'callSign': 'ART305',
#  'status': 'Departed',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'YR-HLA', 'modeS': '4A2181', 'model': 'Boeing 737-800'},
#  'airline': {'name': 'SmartLynx', 'iata': '6Y', 'icao': 'ART'}}

# %%
#extracting arrival icao
response_flight.json()['departures'][0]['arrival']['airport']['icao']
# Out:
# 'HEGN'

# %%
#extracting arrival time
response_flight.json()['departures'][0]['departure']['scheduledTime']['local']
# Out:
# {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#    'local': '2024-03-12 08:40+01:00'},
#   'revisedTime': {'utc': '2024-03-12 08:05Z',
#    'local': '2024-03-12 09:05+01:00'},
#   'runwayTime': {'utc': '2024-03-12 08:11Z',
#    'local': '2024-03-12 09:11+01:00'},
#   'terminal': '1',
#   'checkInDesk': '011-013',
#   'gate': 'C13',
#   'quality': ['Basic', 'Live']},
#  'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#   'quality': []},
#  'number': '6Y 305',
#  'callSign': 'ART305',
#  'status': 'Departed',
#  'codeshareStatus': 'IsOperator',
#  'isCargo': False,
#  'aircraft': {'reg': 'YR-HLA', 'modeS': '4A2181', 'model': 'Boeing 737-800'},
#  'airline': {'name': 'SmartLynx', 'iata': '6Y', 'icao': 'ART'}}

# %%
#extracting departure icao
response_flight.json()['departures'][0]['airline']['icao']
# Out:
# 'EJU'

# %%
#extracting arrival city
response_flight.json()['departures'][0]['arrival']['airport']['name']
# Out:
# 'Rome'

# %%
#Extracting flight number
response_flight.json()['departures'][0]['number']
# Out:
# 'EC 5079'

# %%
#What are current departures or arrivals at the airport? 
#or What is the flight schedule at the airport? 
#or What is flight history at the airport?
import requests
icao_code = 'EDDB'
date = date.today()
start_time = '00:00'
end_time = '12:00'

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao_code}/{date}T{start_time}/{date}T{end_time}"

querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response_arrivals = requests.get(url, headers=headers, params=querystring)

print(response_arrivals.json())
# Out:
# {'departures': [{'departure': {'scheduledTime': {'utc': '2024-03-11 23:21Z', 'local': '2024-03-12 00:21+01:00'}, 'revisedTime': {'utc': '2024-03-11 23:21Z', 'local': '2024-03-12 00:21+01:00'}, 'runwayTime': {'utc': '2024-03-11 23:29Z', 'local': '2024-03-12 00:29+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'}, 'quality': []}, 'number': 'EW 3001', 'callSign': 'EWG3001', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'}, 'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 05:41Z', 'local': '2024-03-12 06:41+01:00'}, 'revisedTime': {'utc': '2024-03-12 05:41Z', 'local': '2024-03-12 06:41+01:00'}, 'runwayTime': {'utc': '2024-03-12 05:48Z', 'local': '2024-03-12 06:48+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'}, 'quality': []}, 'number': '4U 4EP', 'callSign': 'GWI4EP', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-AENH', 'modeS': '3C55C8', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 05:58Z', 'local': '2024-03-12 06:58+01:00'}, 'revisedTime': {'utc': '2024-03-12 05:58Z', 'local': '2024-03-12 06:58+01:00'}, 'runwayTime': {'utc': '2024-03-12 06:11Z', 'local': '2024-03-12 07:11+01:00'}, 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'}, 'quality': []}, 'number': '4U 9AF', 'callSign': 'GWI9AF', 'status': 'Departed', 'codeshareStatus': 'IsOperator', 'isCargo': False, 'aircraft': {'reg': 'D-AENG', 'modeS': '3C55C7', 'model': 'Airbus A320 NEO'}, 'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 06:25Z', 'local': '2024-03-12 07:25+01:00'}, 'revisedTime': {'utc': '2024-03-12 06:25Z', 'local': '2024-03-12 07:25+01:00'}, 'runwayTime': {'utc': '2024-03-12 06:53Z', 'local': '2024-03-12 07:53+01:00'}, 'terminal': '1', 'checkInDesk': '514-616', 'gate': 'A24', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'}, 'quality': []}, 'number': 'EC 5147', 'callSign': 'EJU90YE', 'status': 'Departed', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'OE-ICL', 'modeS': '4404A4', 'model': 'Airbus A320 (Sharklets)'}, 'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z', 'local': '2024-03-12 07:10+01:00'}, 'revisedTime': {'utc': '2024-03-12 06:10Z', 'local': '2024-03-12 07:10+01:00'}, 'terminal': '1', 'checkInDesk': '514-616', 'gate': 'C19', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'}, 'quality': []}, 'number': 'EC 5369', 'status': 'Departed', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'}, 'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 06:00Z', 'local': '2024-03-12 07:00+01:00'}, 'revisedTime': {'utc': '2024-03-12 06:00Z', 'local': '2024-03-12 07:00+01:00'}, 'runwayTime': {'utc': '2024-03-12 06:05Z', 'local': '2024-03-12 07:05+01:00'}, 'terminal': '1', 'checkInDesk': '514-616', 'gate': 'C12', 'quality': ['Basic', 'Live']}, 'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'}, 'quality': []}, 'number': 'EC 8628', 'callSign': 'EJU36QM', 'status': 'Departed', 'codeshareStatus': 'IsCodeshared', 'isCargo': False, 'aircraft': {'reg': 'OE-LQC', 'modeS': '4401E8', 'model': 'Airbus A319'}, 'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}}, {'departure': {'scheduledTime': {'utc': '2024-03-12 06:14Z', 'local': ' ...

# %%
response_arrivals.json()
# Out:
# {'departures': [{'departure': {'scheduledTime': {'utc': '2024-03-11 23:21Z',
#      'local': '2024-03-12 00:21+01:00'},
#     'revisedTime': {'utc': '2024-03-11 23:21Z',
#      'local': '2024-03-12 00:21+01:00'},
#     'runwayTime': {'utc': '2024-03-11 23:29Z',
#      'local': '2024-03-12 00:29+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': 'EW 3001',
#    'callSign': 'EWG3001',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:41Z',
#      'local': '2024-03-12 06:41+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:41Z',
#      'local': '2024-03-12 06:41+01:00'},
#     'runwayTime': {'utc': '2024-03-12 05:48Z',
#      'local': '2024-03-12 06:48+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': '4U 4EP',
#    'callSign': 'GWI4EP',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:58Z',
#      'local': '2024-03-12 06:58+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:58Z',
#      'local': '2024-03-12 06:58+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:11Z',
#      'local': '2024-03-12 07:11+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'quality': []},
#    'number': '4U 9AF',
#    'callSign': 'GWI9AF',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENG',
#     'modeS': '3C55C7',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:53Z',
#      'local': '2024-03-12 07:53+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A24',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'EC 5147',
#    'callSign': 'EJU90YE',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C19',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#     'quality': []},
#    'number': 'EC 5369',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IDO', 'modeS': '4400F3', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:05Z',
#      'local': '2024-03-12 07:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C12',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'number': 'EC 8628',
#    'callSign': 'EJU36QM',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQC', 'modeS': '4401E8', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:14Z',
#      'local': '2024-03-12 07:14+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:14Z',
#      'local': '2024-03-12 07:14+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#     'quality': []},
#    'number': 'EJU 5369',
#    'callSign': 'EJU5369',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-KTP', 'modeS': '4400F3', 'model': 'SB91'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:05Z',
#      'local': '2024-03-12 07:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C12',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGKK', 'iata': 'LGW', 'name': 'London'},
#     'quality': []},
#    'number': 'U2 8628',
#    'callSign': 'EJU36QM',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQC', 'modeS': '4401E8', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:11Z',
#      'local': '2024-03-12 09:11+01:00'},
#     'terminal': '1',
#     'checkInDesk': '011-013',
#     'gate': 'C13',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'HEGN', 'iata': 'HRG', 'name': 'Hurghada'},
#     'quality': []},
#    'number': '6Y 305',
#    'callSign': 'ART305',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'YR-HLA', 'modeS': '4A2181', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'SmartLynx', 'iata': '6Y', 'icao': 'ART'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:42Z',
#      'local': '2024-03-12 08:42+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:42Z',
#      'local': '2024-03-12 08:42+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:42Z',
#      'local': '2024-03-12 08:42+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'BPO 510',
#    'callSign': 'BPO510',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-HEGA', 'modeS': '3DDDCC', 'model': 'AS32'},
#    'airline': {'name': 'BPO'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:20Z',
#      'local': '2024-03-12 08:20+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A32',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIML', 'iata': 'LIN', 'name': 'Milan'},
#     'quality': []},
#    'number': 'EC 5063',
#    'callSign': 'EJU32GN',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-LQW', 'modeS': '440171', 'model': 'Airbus A319'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:58Z',
#      'local': '2024-03-12 08:58+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C14',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'BKPR', 'iata': 'PRN', 'name': 'Prishtina'},
#     'quality': []},
#    'number': 'EC 5365',
#    'callSign': 'EJU5365',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'ESW 77',
#    'callSign': 'ESW77',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '4K-080',
#     'modeS': '600BCA',
#     'model': 'Gulfstream Aerospace V'},
#    'airline': {'name': 'ESW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:06Z',
#      'local': '2024-03-12 09:06+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'DFBWG',
#    'callSign': 'DFBWG',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-FBWG', 'modeS': '3D4E36', 'model': 'Pilatus PC-12'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:30Z',
#      'local': '2024-03-12 09:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:30Z',
#      'local': '2024-03-12 09:30+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A36',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIRN', 'iata': 'NAP', 'name': 'Nápoli'},
#     'quality': []},
#    'number': 'EC 5051',
#    'callSign': 'EJU5051',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IJW', 'modeS': '44093E', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:09Z',
#      'local': '2024-03-12 09:09+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'LXG 74M',
#    'callSign': 'LXG74M',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ICBA', 'modeS': '3E1CAA', 'model': 'Cessna 525A'},
#    'airline': {'name': 'LXG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'quality': []},
#    'number': 'LH 5386',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:33Z',
#      'local': '2024-03-12 09:33+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:33Z',
#      'local': '2024-03-12 09:33+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:36Z',
#      'local': '2024-03-12 09:36+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'name': 'Unknown'}, 'quality': []},
#    'number': 'QGA 1A',
#    'callSign': 'QGA01A',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-CJJK',
#     'modeS': '3CD8B8',
#     'model': 'Cessna 560 Citation Excel'},
#    'airline': {'name': 'QGA'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:12Z',
#      'local': '2024-03-12 10:12+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A31',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'EC 4076',
#    'callSign': 'EJU14KB',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICP', 'modeS': '440036', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 10:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 10:35+01:00'},
#     'terminal': '1',
#     'checkInDesk': '214-216',
#     'gate': 'A32',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LDDU', 'iata': 'DBV', 'name': 'Dubrovnik'},
#     'quality': []},
#    'number': 'MI 8173',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-FHB', 'modeS': '4D21B1', 'model': 'Airbus A320'},
#    'airline': {'name': 'Freebird Airlines Europe'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:58Z',
#      'local': '2024-03-12 08:58+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C14',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'BKPR', 'iata': 'PRN', 'name': 'Prishtina'},
#     'scheduledTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'quality': ['Basic']},
#    'number': 'U2 5365',
#    'callSign': 'EZY5365',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-INA', 'modeS': '440159', 'model': 'Airbus A320'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:03Z',
#      'local': '2024-03-12 07:03+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:03Z',
#      'local': '2024-03-12 07:03+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:03Z',
#      'local': '2024-03-12 07:03+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBAW', 'iata': 'ANR', 'name': 'Antwerp'},
#     'scheduledTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'GAC 393D',
#    'callSign': 'GAC393D',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-FWF',
#     'modeS': '4405DA',
#     'model': 'Cessna 510 Citation Mustang'},
#    'airline': {'name': 'GAC'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:16Z',
#      'local': '2024-03-12 07:16+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'A02',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:19Z',
#      'local': '2024-03-12 08:19+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:13Z',
#      'local': '2024-03-12 08:13+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2592',
#    'callSign': 'BEL8YE',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNJ',
#     'modeS': '44CDCA',
#     'model': 'Airbus A320-200'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B10',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EBBR', 'iata': 'BRU', 'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 12:20Z',
#      'local': '2024-03-12 13:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 12:20Z',
#      'local': '2024-03-12 13:20+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2582',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNJ', 'model': 'Airbus A320-200'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:25Z',
#      'local': '2024-03-12 06:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:25Z',
#      'local': '2024-03-12 06:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 06:40Z',
#      'local': '2024-03-12 07:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:40Z',
#      'local': '2024-03-12 07:40+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 173',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIRT',
#     'modeS': '3C6654',
#     'model': 'Airbus A321-100'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:40Z',
#      'local': '2024-03-12 07:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:40Z',
#      'local': '2024-03-12 07:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 07:55Z',
#      'local': '2024-03-12 08:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:55Z',
#      'local': '2024-03-12 08:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 175',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIEN',
#     'modeS': '3C64AE',
#     'model': 'Airbus A321 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 08:25+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 45',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIZA',
#     'modeS': '3C6741',
#     'model': 'Airbus A320-200'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:12Z',
#      'local': '2024-03-12 09:12+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:53Z',
#      'local': '2024-03-12 09:53+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'DISAG',
#    'callSign': 'DISAG',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ISAG',
#     'modeS': '3E46D6',
#     'model': 'Beechcraft Premier I'},
#    'airline': {'name': 'Unknown/Private owner'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 177',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 09:55Z',
#      'local': '2024-03-12 10:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:55Z',
#      'local': '2024-03-12 10:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 181',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:40Z',
#      'local': '2024-03-12 10:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:40Z',
#      'local': '2024-03-12 10:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 183',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:40Z',
#      'local': '2024-03-12 11:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:40Z',
#      'local': '2024-03-12 11:40+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-426',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:55Z',
#      'local': '2024-03-12 12:55+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 185',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 07:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'B01',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-12 07:10Z',
#      'local': '2024-03-12 08:10+01:00'},
#     'terminal': '1',
#     'quality': ['Basic']},
#    'number': 'EW 8058',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENG',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:35Z',
#      'local': '2024-03-12 08:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:35Z',
#      'local': '2024-03-12 08:35+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:49Z',
#      'local': '2024-03-12 08:49+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'B01',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDK', 'iata': 'CGN', 'name': 'Cologne'},
#     'scheduledTime': {'utc': '2024-03-12 08:45Z',
#      'local': '2024-03-12 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:32Z',
#      'local': '2024-03-12 09:32+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 13',
#    'callSign': 'EWG7CV',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-ABHG', 'modeS': '3C4907', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'B25',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-12 06:55Z',
#      'local': '2024-03-12 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:39Z',
#      'local': '2024-03-12 07:39+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:36Z',
#      'local': '2024-03-12 07:36+01:00'},
#     'terminal': 'A(1)',
#     'gate': 'A42',
#     'baggageBelt': '04',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8040',
#    'callSign': 'GWI40M',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWT', 'modeS': '3C56F4', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:05Z',
#      'local': '2024-03-12 09:05+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'B03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTime': {'utc': '2024-03-12 09:15Z',
#      'local': '2024-03-12 10:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:01Z',
#      'local': '2024-03-12 10:01+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:58Z',
#      'local': '2024-03-12 09:58+01:00'},
#     'terminal': 'A(1)',
#     'gate': 'B33',
#     'baggageBelt': '04',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 9049',
#    'callSign': 'GWI9UW',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDV', 'modeS': '3C6496', 'model': 'Airbus A321'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:15Z',
#      'local': '2024-03-12 06:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:15Z',
#      'local': '2024-03-12 06:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'A10',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1957',
#    'callSign': 'DLH7EL',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIUB',
#     'modeS': '3C66A2',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:15Z',
#      'local': '2024-03-12 07:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:15Z',
#      'local': '2024-03-12 07:15+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:21Z',
#      'local': '2024-03-12 07:21+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B19',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 08:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:10Z',
#      'local': '2024-03-12 08:10+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:10Z',
#      'local': '2024-03-12 08:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1959',
#    'callSign': 'DLH7VV',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AISJ', 'modeS': '3C666A', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:08Z',
#      'local': '2024-03-12 09:08+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B07',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 09:10Z',
#      'local': '2024-03-12 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:50Z',
#      'local': '2024-03-12 09:50+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1929',
#    'callSign': 'DLH3TT',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AINW',
#     'modeS': '3C65D7',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:15Z',
#      'local': '2024-03-12 10:15+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B01',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 10:10Z',
#      'local': '2024-03-12 11:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:10Z',
#      'local': '2024-03-12 11:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1931',
#    'callSign': 'DLH9JK',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIBF', 'modeS': '3C6446', 'model': 'Airbus A319'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '421-424',
#     'gate': 'B06',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDM', 'iata': 'MUC', 'name': 'Munich'},
#     'scheduledTime': {'utc': '2024-03-12 11:10Z',
#      'local': '2024-03-12 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 11:10Z',
#      'local': '2024-03-12 12:10+01:00'},
#     'terminal': '2',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 1935',
#    'status': 'Boarding',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AIDJ', 'modeS': '3C648A', 'model': 'Airbus A321'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:54Z',
#      'local': '2024-03-12 08:54+01:00'},
#     'terminal': '1',
#     'checkInDesk': '521-522',
#     'gate': 'B30',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDR',
#      'iata': 'SCN',
#      'name': 'Saarbrücken'},
#     'scheduledTime': {'utc': '2024-03-12 09:20Z',
#      'local': '2024-03-12 10:20+01:00'},
#     'quality': ['Basic']},
#    'number': 'DX 122',
#    'callSign': 'DTR2HR',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-RUO', 'modeS': '45CAAF', 'model': 'ATR 42'},
#    'airline': {'name': 'Danish Air', 'iata': 'DX', 'icao': 'DTR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A22',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 06:55Z',
#      'local': '2024-03-12 07:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:43Z',
#      'local': '2024-03-12 07:43+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 8000',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:04Z',
#      'local': '2024-03-12 09:04+01:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 09:55+01:00'},
#     'quality': ['Basic', 'Live']},
#    'number': '4U 2003',
#    'callSign': 'GWI2003',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Germanwings', 'iata': '4U', 'icao': 'GWI'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:00Z',
#      'local': '2024-03-12 09:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDS', 'iata': 'STR', 'name': 'Stuttgart'},
#     'scheduledTime': {'utc': '2024-03-12 09:10Z',
#      'local': '2024-03-12 10:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'terminal': '3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EW 2003',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AEWR', 'modeS': '3C56F2', 'model': 'Airbus A320'},
#    'airline': {'name': 'Eurowings', 'iata': 'EW', 'icao': 'EWG'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 08:45+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:56Z',
#      'local': '2024-03-12 08:56+01:00'},
#     'terminal': '1',
#     'checkInDesk': '223-225',
#     'gate': 'A17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-12 09:35Z',
#      'local': '2024-03-12 11:35+02:00'},
#     'revisedTime': {'utc': '2024-03-12 09:34Z',
#      'local': '2024-03-12 11:34+02:00'},
#     'terminal': '2',
#     'gate': '20',
#     'baggageBelt': '8',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1432',
#    'callSign': 'FIN29Y',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LKM', 'modeS': '461E1C', 'model': 'Embraer 190'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:45Z',
#      'local': '2024-03-12 06:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '323-326',
#     'gate': 'A22',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGBB',
#      'iata': 'BHX',
#      'name': 'Birmingham'},
#     'scheduledTime': {'utc': '2024-03-12 07:25Z',
#      'local': '2024-03-12 07:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 07:22Z',
#      'local': '2024-03-12 07:22+00:00'},
#     'runwayTime': {'utc': '2024-03-12 07:19Z',
#      'local': '2024-03-12 07:19+00:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 5391',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'D-AENH',
#     'modeS': '3C55C8',
#     'model': 'Airbus A320 NEO'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C06',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'scheduledTime': {'utc': '2024-03-12 12:25Z',
#      'local': '2024-03-12 12:25+00:00'},
#     'quality': ['Basic']},
#    'number': 'U2 2934',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZGJ', 'modeS': '406539', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 09:30Z',
#      'local': '2024-03-12 10:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'C04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGGW', 'iata': 'LTN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 11:25Z',
#      'local': '2024-03-12 11:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 11:20Z',
#      'local': '2024-03-12 11:20+00:00'},
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2602',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZDR', 'modeS': '405B6A', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:55Z',
#      'local': '2024-03-12 06:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:55Z',
#      'local': '2024-03-12 06:55+01:00'},
#     'runwayTime': {'utc': '2024-03-12 05:58Z',
#      'local': '2024-03-12 06:58+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'C04',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 07:50Z',
#      'local': '2024-03-12 07:50+00:00'},
#     'revisedTime': {'utc': '2024-03-12 07:28Z',
#      'local': '2024-03-12 07:28+00:00'},
#     'gate': '8',
#     'baggageBelt': '02',
#     'runway': '27',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8490',
#    'callSign': 'CFE8N',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYT', 'modeS': '406B6D', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'C17',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 12:40Z',
#      'local': '2024-03-12 12:40+00:00'},
#     'revisedTime': {'utc': '2024-03-12 12:40Z',
#      'local': '2024-03-12 12:40+00:00'},
#     'gate': '6',
#     'baggageBelt': '01',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8492',
#    'callSign': 'CFE34E',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYT', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:05Z',
#      'local': '2024-03-12 07:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:05Z',
#      'local': '2024-03-12 07:05+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:14Z',
#      'local': '2024-03-12 07:14+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'D03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 08:10Z',
#      'local': '2024-03-12 08:10+00:00'},
#     'revisedTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 07:45+00:00'},
#     'runwayTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 07:45+00:00'},
#     'terminal': '5',
#     'baggageBelt': '4',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 981',
#    'callSign': 'BAW4CB',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUYO',
#     'modeS': '40688A',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:00Z',
#      'local': '2024-03-12 11:00+01:00'},
#     'terminal': '1',
#     'checkInDesk': '221-225',
#     'gate': 'C07',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 12:05Z',
#      'local': '2024-03-12 12:05+00:00'},
#     'revisedTime': {'utc': '2024-03-12 12:05Z',
#      'local': '2024-03-12 12:05+00:00'},
#     'terminal': '5',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 991',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUPP', 'modeS': '4008B1', 'model': 'Airbus A319'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:15Z',
#      'local': '2024-03-12 08:15+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:22Z',
#      'local': '2024-03-12 08:22+01:00'},
#     'terminal': '2',
#     'checkInDesk': '156-165',
#     'gate': 'B45',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EGSS', 'iata': 'STN', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 09:05Z',
#      'local': '2024-03-12 09:05+00:00'},
#     'revisedTime': {'utc': '2024-03-12 08:55Z',
#      'local': '2024-03-12 08:55+00:00'},
#     'terminal': '1',
#     'gate': '86',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 144',
#    'callSign': 'RYR470R',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QAU', 'modeS': '4D2269', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 05:00Z',
#      'local': '2024-03-12 06:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 05:00Z',
#      'local': '2024-03-12 06:00+01:00'},
#     'runwayTime': {'utc': '2024-03-12 05:09Z',
#      'local': '2024-03-12 06:09+01:00'},
#     'terminal': '1',
#     'checkInDesk': '811-816',
#     'gate': 'A07',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:03Z',
#      'local': '2024-03-12 07:03+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:03Z',
#      'local': '2024-03-12 07:03+01:00'},
#     'terminal': '2',
#     'baggageBelt': '13',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1818',
#    'callSign': 'KLM44R',
#    'status': 'Departed',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCB', 'modeS': '484F18', 'model': 'Boeing 737'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:23Z',
#      'local': '2024-03-12 07:23+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A37',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:20Z',
#      'local': '2024-03-12 08:20+01:00'},
#     'runwayTime': {'utc': '2024-03-12 07:20Z',
#      'local': '2024-03-12 08:20+01:00'},
#     'terminal': '3',
#     'baggageBelt': '15',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5281',
#    'callSign': 'EJU96ZQ',
#    'status': 'Departed',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-IBF', 'modeS': '440CF8', 'model': 'Airbus A320'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'scheduledTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:10Z',
#      'local': '2024-03-12 07:10+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:23Z',
#      'local': '2024-03-12 07:23+01:00'},
#     'terminal': '1',
#     'checkInDesk': '514-616',
#     'gate': 'A37',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EHAM', 'iata': 'AMS', 'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-12 07:40Z',
#      'local': '2024-03-12 08:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 07:20Z',
# ...
#     'scheduledTime': {'utc': '2024-03-12 06:15Z',
#      'local': '2024-03-12 07:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 06:11Z',
#      'local': '2024-03-12 07:11+01:00'},
#     'runwayTime': {'utc': '2024-03-12 06:25Z',
#      'local': '2024-03-12 07:25+01:00'},
#     'terminal': '1',
#     'checkInDesk': '501-514',
#     'gate': 'B39',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:42Z',
#      'local': '2024-03-12 09:42+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:42Z',
#      'local': '2024-03-12 09:42+01:00'},
#     'terminal': '2',
#     'gate': 'Z34',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'VY 1882',
#    'callSign': 'VLG1882',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EC-MMU', 'modeS': '345249', 'model': 'Airbus A321'},
#    'airline': {'name': 'Vueling', 'iata': 'VY', 'icao': 'VLG'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-12 08:45Z',
#      'local': '2024-03-12 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:17Z',
#      'local': '2024-03-12 10:17+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:17Z',
#      'local': '2024-03-12 10:17+01:00'},
#     'terminal': '2F',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:30Z',
#      'local': '2024-03-12 11:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:34Z',
#      'local': '2024-03-12 11:34+01:00'},
#     'terminal': '1',
#     'gate': 'B07',
#     'baggageBelt': 'B2',
#     'quality': ['Basic', 'Live']},
#    'number': 'AF 1734',
#    'callSign': 'AFR69NH',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAT', 'modeS': '394C13', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air France', 'iata': 'AF', 'icao': 'AFR'}},
#   {'departure': {'airport': {'icao': 'EGLC', 'iata': 'LCY', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 08:25Z',
#      'local': '2024-03-12 08:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 08:20Z',
#      'local': '2024-03-12 08:20+00:00'},
#     'runwayTime': {'utc': '2024-03-12 08:26Z',
#      'local': '2024-03-12 08:26+00:00'},
#     'gate': '8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:05Z',
#      'local': '2024-03-12 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:40Z',
#      'local': '2024-03-12 10:40+01:00'},
#     'terminal': '1',
#     'gate': 'X17',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 8491',
#    'callSign': 'CFE76JZ',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-LCYT', 'modeS': '406B6D', 'model': 'Embraer 190'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EGLL', 'iata': 'LHR', 'name': 'London'},
#     'scheduledTime': {'utc': '2024-03-12 08:25Z',
#      'local': '2024-03-12 08:25+00:00'},
#     'revisedTime': {'utc': '2024-03-12 08:49Z',
#      'local': '2024-03-12 08:49+00:00'},
#     'runwayTime': {'utc': '2024-03-12 08:50Z',
#      'local': '2024-03-12 08:50+00:00'},
#     'terminal': '5',
#     'checkInDesk': 'D',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:11Z',
#      'local': '2024-03-12 11:11+01:00'},
#     'terminal': '1',
#     'gate': 'X10',
#     'baggageBelt': 'A1',
#     'quality': ['Basic', 'Live']},
#    'number': 'BA 992',
#    'callSign': 'BAW992G',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EUUT', 'modeS': '401240', 'model': 'Airbus A320'},
#    'airline': {'name': 'British Airways', 'iata': 'BA', 'icao': 'BAW'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'terminal': '2',
#     'checkInDesk': '884-885',
#     'gate': 'D23',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:15Z',
#      'local': '2024-03-12 11:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'terminal': '1',
#     'gate': 'A32',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'C3 436',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9A-BTK', 'modeS': '501C1C', 'model': 'Airbus A320'},
#    'airline': {'name': 'Trade Air', 'iata': 'C3', 'icao': 'TDR'}},
#   {'departure': {'airport': {'icao': 'EGGD', 'iata': 'BRS', 'name': 'Bristol'},
#     'scheduledTime': {'utc': '2024-03-12 07:45Z',
#      'local': '2024-03-12 07:45+00:00'},
#     'revisedTime': {'utc': '2024-03-12 07:51Z',
#      'local': '2024-03-12 07:51+00:00'},
#     'runwayTime': {'utc': '2024-03-12 07:51Z',
#      'local': '2024-03-12 07:51+00:00'},
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:28Z',
#      'local': '2024-03-12 10:28+01:00'},
#     'terminal': '1',
#     'gate': 'X06',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 2933',
#    'callSign': 'EZY80CB',
#    'status': 'Arrived',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'G-EZGJ', 'modeS': '406539', 'model': 'Airbus A319'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:35Z',
#      'local': '2024-03-12 11:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:35Z',
#      'local': '2024-03-12 11:35+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'EC 5148',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'EasyJet Europe', 'iata': 'EC', 'icao': 'EJU'}},
#   {'departure': {'airport': {'icao': 'LEBL',
#      'iata': 'BCN',
#      'name': 'Barcelona'},
#     'scheduledTime': {'utc': '2024-03-12 08:15Z',
#      'local': '2024-03-12 09:15+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:11Z',
#      'local': '2024-03-12 09:11+01:00'},
#     'runwayTime': {'utc': '2024-03-12 08:32Z',
#      'local': '2024-03-12 09:32+01:00'},
#     'terminal': '2',
#     'checkInDesk': 'B67-B71',
#     'gate': 'S21',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:51Z',
#      'local': '2024-03-12 11:51+01:00'},
#     'terminal': '2',
#     'gate': 'Z33',
#     'baggageBelt': 'C1',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 133',
#    'callSign': 'RYR40XD',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': '9H-QCV', 'modeS': '4D2244', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}},
#   {'departure': {'airport': {'icao': 'EHAM',
#      'iata': 'AMS',
#      'name': 'Amsterdam'},
#     'scheduledTime': {'utc': '2024-03-12 08:45Z',
#      'local': '2024-03-12 09:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:02Z',
#      'local': '2024-03-12 10:02+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:11Z',
#      'local': '2024-03-12 10:11+01:00'},
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'gate': 'D86',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:05Z',
#      'local': '2024-03-12 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:03Z',
#      'local': '2024-03-12 11:03+01:00'},
#     'terminal': '1',
#     'gate': 'A30',
#     'baggageBelt': 'A2',
#     'quality': ['Basic', 'Live']},
#    'number': 'KL 1823',
#    'callSign': 'KLM95E',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM', 'iata': 'KL', 'icao': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDF',
#      'iata': 'FRA',
#      'name': 'Frankfurt-am-Main'},
#     'scheduledTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:45Z',
#      'local': '2024-03-12 10:45+01:00'},
#     'terminal': '1',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:55Z',
#      'local': '2024-03-12 11:55+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'LH 180',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A320-200 (sharklets)'},
#    'airline': {'name': 'Lufthansa', 'iata': 'LH', 'icao': 'DLH'}},
#   {'departure': {'airport': {'icao': 'LTAI', 'iata': 'AYT', 'name': 'Antalya'},
#     'scheduledTime': {'utc': '2024-03-12 06:45Z',
#      'local': '2024-03-12 09:45+03:00'},
#     'revisedTime': {'utc': '2024-03-12 06:45Z',
#      'local': '2024-03-12 09:45+03:00'},
#     'terminal': '1',
#     'checkInDesk': '145-147',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:20Z',
#      'local': '2024-03-12 11:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:02Z',
#      'local': '2024-03-12 11:02+01:00'},
#     'terminal': '1',
#     'gate': 'Y03',
#     'baggageBelt': 'B3',
#     'quality': ['Basic', 'Live']},
#    'number': 'PC 5007',
#    'callSign': 'PGT99EZ',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TC-NBA',
#     'modeS': '4BB841',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Pegasus', 'iata': 'PC', 'icao': 'PGT'}},
#   {'departure': {'airport': {'icao': 'ESSA',
#      'iata': 'ARN',
#      'name': 'Stockholm'},
#     'scheduledTime': {'utc': '2024-03-12 08:30Z',
#      'local': '2024-03-12 09:30+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:27Z',
#      'local': '2024-03-12 09:27+01:00'},
#     'terminal': '5',
#     'checkInDesk': '71-80',
#     'gate': 'E5',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:05Z',
#      'local': '2024-03-12 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 09:49Z',
#      'local': '2024-03-12 10:49+01:00'},
#     'terminal': '1',
#     'gate': 'B17',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SK 2677',
#    'callSign': 'SAS2677',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OY-KAW', 'modeS': '45AC37', 'model': 'Airbus A320'},
#    'airline': {'name': 'SAS', 'iata': 'SK', 'icao': 'SAS'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTime': {'utc': '2024-03-12 08:40Z',
#      'local': '2024-03-12 09:40+01:00'},
#     'revisedTime': {'utc': '2024-03-12 08:59Z',
#      'local': '2024-03-12 09:59+01:00'},
#     'runwayTime': {'utc': '2024-03-12 09:00Z',
#      'local': '2024-03-12 10:00+01:00'},
#     'checkInDesk': '05',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:05Z',
#      'local': '2024-03-12 11:05+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:02Z',
#      'local': '2024-03-12 11:02+01:00'},
#     'terminal': '1',
#     'gate': 'B10',
#     'baggageBelt': 'B4',
#     'quality': ['Basic', 'Live']},
#    'number': 'SN 2581',
#    'callSign': 'BEL8CE',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OO-SNJ',
#     'modeS': '44CDCA',
#     'model': 'Airbus A320-200'},
#    'airline': {'name': 'Brussels', 'iata': 'SN', 'icao': 'BEL'}},
#   {'departure': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'scheduledTime': {'utc': '2024-03-12 08:45Z',
#      'local': '2024-03-12 09:45+01:00'},
#     'terminal': '2B',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 10:35Z',
#      'local': '2024-03-12 11:35+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:35Z',
#      'local': '2024-03-12 11:35+01:00'},
#     'terminal': '1',
#     'gate': 'A03',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'U2 5148',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OE-ICL',
#     'modeS': '4404A4',
#     'model': 'Airbus A320 (Sharklets)'},
#    'airline': {'name': 'easyJet', 'iata': 'U2', 'icao': 'EZY'}},
#   {'departure': {'airport': {'icao': 'EFHK',
#      'iata': 'HEL',
#      'name': 'Helsinki'},
#     'scheduledTime': {'utc': '2024-03-12 09:20Z',
#      'local': '2024-03-12 11:20+02:00'},
#     'revisedTime': {'utc': '2024-03-12 09:09Z',
#      'local': '2024-03-12 11:09+02:00'},
#     'runwayTime': {'utc': '2024-03-12 09:18Z',
#      'local': '2024-03-12 11:18+02:00'},
#     'terminal': '2',
#     'checkInDesk': '211',
#     'gate': '23',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 11:20Z',
#      'local': '2024-03-12 12:20+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:52Z',
#      'local': '2024-03-12 11:52+01:00'},
#     'terminal': '1',
#     'gate': 'A02',
#     'baggageBelt': 'A3',
#     'quality': ['Basic', 'Live']},
#    'number': 'AY 1433',
#    'callSign': 'FIN8WP',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'OH-LZL',
#     'modeS': '461FA1',
#     'model': 'Airbus A321 (Sharklets)'},
#    'airline': {'name': 'Finnair', 'iata': 'AY', 'icao': 'FIN'}},
#   {'departure': {'airport': {'icao': 'BIKF',
#      'iata': 'KEF',
#      'name': 'Reykjavik'},
#     'scheduledTime': {'utc': '2024-03-12 07:30Z',
#      'local': '2024-03-12 07:30+00:00'},
#     'revisedTime': {'utc': '2024-03-12 07:29Z',
#      'local': '2024-03-12 07:29+00:00'},
#     'runwayTime': {'utc': '2024-03-12 07:42Z',
#      'local': '2024-03-12 07:42+00:00'},
#     'gate': 'C28',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 11:00Z',
#      'local': '2024-03-12 12:00+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:49Z',
#      'local': '2024-03-12 11:49+01:00'},
#     'terminal': '1',
#     'gate': 'A33',
#     'baggageBelt': 'A4',
#     'quality': ['Basic', 'Live']},
#    'number': 'FI 528',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'TF-ICE', 'modeS': '4CC50E', 'model': 'Boeing 737'},
#    'airline': {'name': 'Icelandair', 'iata': 'FI', 'icao': 'ICE'}},
#   {'departure': {'airport': {'icao': 'GCTS',
#      'iata': 'TFS',
#      'name': 'Tenerife Island'},
#     'scheduledTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 06:00+00:00'},
#     'revisedTime': {'utc': '2024-03-12 06:00Z',
#      'local': '2024-03-12 06:00+00:00'},
#     'terminal': 'C',
#     'checkInDesk': '202-205',
#     'gate': 'B32,B31',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTime': {'utc': '2024-03-12 11:10Z',
#      'local': '2024-03-12 12:10+01:00'},
#     'revisedTime': {'utc': '2024-03-12 10:35Z',
#      'local': '2024-03-12 11:35+01:00'},
#     'terminal': '2',
#     'gate': 'Z36',
#     'baggageBelt': 'C3',
#     'quality': ['Basic', 'Live']},
#    'number': 'FR 2419',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'reg': 'EI-EVT', 'modeS': '4CAA59', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Ryanair', 'iata': 'FR', 'icao': 'RYR'}}]}

# %%
#extracting arrival icao
response_arrivals.json()['departures'][0]['arrival']['airport']['icao']
#extracting departure icao
response_arrivals.json()['departures'][0]['airline']['icao']
#extracting arrival city
response_arrivals.json()['departures'][0]['arrival']['airport']['name']
#Extracting flight number
response_arrivals.json()['departures'][0]['number']
#extracting arrival time
response_arrivals.json()['departures'][0]['departure']['scheduledTime']['local']
# Out:
# '2024-03-12 00:21+01:00'

# %%
icao_code = 'EDDB'
date = date.today()
start_time = '00:00'
end_time = '12:00'

url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao_code}/{date}T{start_time}/{date}T{end_time}"

querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
    "X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4",
    "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response_arrivals1 = requests.get(url, headers=headers, params=querystring)
arrivals = response_arrivals1.json()
flight_list = []
for item in arrivals['departures']:
    flight_item = {
    #extracting arrival icao
    'arrival_icao': item['arrival']['airport'].get('icao', None),
    #extracting departure icao
    'departure_icao': item['airline'].get('icao', None),
    #extracting arrival city
    'arrival_city': item['arrival']['airport']['name'],
    #Extracting flight number
    'flight_number': item.get('number', None),
    #extracting arrival time
    'arrival_time': item['departure']['scheduledTime']['local']
    }
    
    flight_list.append(flight_item)
    flight_df = pd.DataFrame(flight_list)

flight_df['arrival_time'] =  flight_df['arrival_time'].str[:-6] #getting rid of +01:00 from arrival_time
flight_df
# Out:
#     arrival_icao departure_icao arrival_city flight_number      arrival_time
# 0           EDDS            EWG    Stuttgart       EW 3001  2024-03-12 00:21
# 1           EDDS            GWI    Stuttgart        4U 4EP  2024-03-12 06:41
# 2           EDDK            GWI      Cologne        4U 9AF  2024-03-12 06:58
# 3           LFPG            EJU        Paris       EC 5147  2024-03-12 07:25
# 4           HEGN            EJU     Hurghada       EC 5369  2024-03-12 07:10
# ..           ...            ...          ...           ...               ...
# 109         LTFM            THY     Istanbul       TK 1728  2024-03-12 06:40
# 110         LTFM            THY     Istanbul       TK 1722  2024-03-12 11:10
# 111         OTHH            QTR         Doha         QR 80  2024-03-12 09:00
# 112         UBBB            AHY         Baku         J2 64  2024-03-12 09:55
# 113         UGKO            WZZ      Kutaisi       W6 6408  2024-03-12 08:35
#
# [114 rows x 5 columns]

# %%
flight_df['arrival_time'] =  flight_df['arrival_time'].str[:-6] #getting rid of +01:00 from arrival_time
flight_df.head()
# Out:
#   arrival_icao departure_icao arrival_city flight_number      arrival_time
# 0         EDDS            EWG    Stuttgart       EW 3001  2024-03-12 00:21
# 1         EDDS            GWI    Stuttgart        4U 4EP  2024-03-12 06:41
# 2         EDDK            GWI      Cologne        4U 9AF  2024-03-12 06:58
# 3         LFPG            EJU        Paris       EC 5147  2024-03-12 07:25
# 4         HEGN            EJU     Hurghada       EC 5369  2024-03-12 07:10

# %%
import requests
from datetime import date, timedelta
import pandas as pd

def get_and_send_flight_data():
    connection_string = connection()
    airport_df = pd.read_sql('airport', con= connection_string)
    flight_df = get_flight_data(airport_df)
    send_flight_data(flight_df, connection_string)
    return 'Flights data sent'




def connection():
  schema = "sql_challenge1"
  host = "127.0.0.1"
  user = "root"
  password = "root1234"
  port = 3306
  connection_string =  f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
  return connection_string


def get_flight_data(airport_df):
    present_day = date.today()
    tomorrow= present_day + timedelta(1)

    
    flight_list = []
    
    for icao_code in airport_df['icao']:
        times = [['00:00', '11:59'], ['12:00', '23:59']]

        for time in times:

            url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao_code}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

            querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

            headers = {
                "X-RapidAPI-Key": "14a44098c8mshe4536a007985112p1e3b4bjsn8fd805eb6bd4",
                "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
            }

            response_arrivals1 = requests.get(url, headers=headers, params=querystring)
            arrivals = response_arrivals1.json()
            icao_list = airport_df["icao"].tolist()

            
            for item in arrivals['departures']:
                flight_item = {
                #extracting arrival icao
                'arrival_icao': icao_list[0],
                #extracting departure icao
                'departure_icao': item['airline'].get('icao', None),
                #extracting arrival city
                'arrival_city': item['arrival']['airport']['name'],
                #Extracting flight number
                'flight_number': item.get('number', None),
                #extracting arrival time
                'arrival_time': item['departure']['scheduledTime']['local']
                }
                
                flight_list.append(flight_item)
                flight_df = pd.DataFrame(flight_list)

            flight_df['arrival_time'] =  flight_df['arrival_time'].str[:-6] #getting rid of +01:00 from arrival_time
            flight_df['arrival_time'] = pd.to_datetime(flight_df['arrival_time'])
            
    print (flight_df.info())
    return flight_df

def send_flight_data(flight_df, connection_string):
  flight_df.to_sql('flight',
                    if_exists='append',
                    con=connection_string,
                    index=False)
  
get_and_send_flight_data()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2968 entries, 0 to 2967
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   arrival_icao    2968 non-null   object
#  1   departure_icao  2907 non-null   object
#  2   arrival_city    2968 non-null   object
#  3   flight_number   2968 non-null   object
#  4   arrival_time    2968 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(4)
# memory usage: 116.1+ KB
# None
# 'Flights data sent'

# %%
import pandas as pd
import pymysql

def get_and_send_airport_cities_data():
   connection_string = connection()
   cities = pd.read_sql('cities', con= connection_string)
   airport_df = pd.read_sql('airport', con=connection_string)
   cities_airports_df = get_cities_airport_data(cities, airport_df)
   send_cities_airport_data(cities_airports_df, connection_string)
   return 'airport_cities data was sent'




def connection():
  schema = "sql_challenge1"
  host = "127.0.0.1"
  user = "root"
  password = "root1234"
  port = 3306
  connection_string =  f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'
  return connection_string



def get_cities_airport_data(cities, airport_df):
    
    city_id = list(cities['city_id'])[0]
    airport_icao= list(airport_df['icao'])[0]

    cities_airports_list = []
    cities_airports_dict = {
       'city_id':city_id,
       'airport_icao':airport_icao

    }
    cities_airports_list.append(cities_airports_dict)
    cities_airports_df = pd.DataFrame(cities_airports_list)
    print(cities_airports_df.info())
    return cities_airports_df


def send_cities_airport_data(cities_airports_df, connection_string):
  cities_airports_df.to_sql('cities_airports',
                    if_exists='append',
                    con=connection_string,
                    index=False)
  
get_and_send_airport_cities_data()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   city_id       1 non-null      int64
#  1   airport_icao  1 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 148.0+ bytes
# None
# 'airport_cities data was sent'
